# %% [markdown]
# ## Carbon Black Testing

# %%
import tweepy

# Calling help and various twitter.api modules
help(tweepy.auth)
#help(tweepy.api)


# Keys needed for authentication purposes
consumer_key = "JRSzaMcADzpjqWiu8mviGeJWx"
consumer_secret = "T0gDLHl7o9FYx0VJ18h6oiR68kPwi7qIcLoeHGQEWBMmj7k2vj"
access_token = "100592963-hFkQOpwfnhksoV8kywWOQqTDeKrE863qrtgmCNKn"
access_token_secret = "hP7GsXMDMxm2o7Wx3hLokaL75XzzwBiXPYXpU4YbsYpOz"

# Authentication is done below

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)


# Simple look ups via the Twitter API refer to Twitter documentation


users = api.lookup_users(screen_names='isaacrael')
print(users)
# Out:
# Help on module tweepy.auth in tweepy:
#
# NAME
#     tweepy.auth
#
# FILE
#     /home/isaac/.virtualenvs/sci_py/lib/python2.7/site-packages/tweepy/auth.py
#
# CLASSES
#     __builtin__.object
#         AuthHandler
#             AppAuthHandler
#             OAuthHandler
#     requests.auth.AuthBase(__builtin__.object)
#         OAuth2Bearer
#
#     class AppAuthHandler(AuthHandler)
#      |  Application-only authentication handler
#      |
#      |  Method resolution order:
#      |      AppAuthHandler
#      |      AuthHandler
#      |      __builtin__.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, consumer_key, consumer_secret)
#      |
#      |  apply_auth(self)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  OAUTH_HOST = 'api.twitter.com'
#      |
#      |  OAUTH_ROOT = '/oauth2/'
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from AuthHandler:
#      |
#      |  get_username(self)
#      |      Return the username of the authenticated user
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from AuthHandler:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#
#     class AuthHandler(__builtin__.object)
#      |  Methods defined here:
#      |
#      |  apply_auth(self, url, method, headers, parameters)
#      |      Apply authentication headers to request
#      |
#      |  get_username(self)
#      |      Return the username of the authenticated user
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#
#     class OAuth2Bearer(requests.auth.AuthBase)
#      |  Method resolution order:
#      |      OAuth2Bearer
#      |      requests.auth.AuthBase
#      |      __builtin__.object
#      |
#      |  Methods defined here:
#      |
#      |  __call__(self, request)
#      |
#      |  __init__(self, bearer_token)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from requests.auth.AuthBase:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#
#     class OAuthHandler(AuthHandler)
#      |  OAuth authentication handler
#      |
#      |  Method resolution order:
#      |      OAuthHandler
#      |      AuthHandler
#      |      __builtin__.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, consumer_key, consumer_secret, callback=None)
#      |
#      |  apply_auth(self)
#      |
#      |  get_access_token(self, verifier=None)
#      |      After user has authorized the request token, get access token
#      |      with user supplied verifier.
#      |
#      |  get_authorization_url(self, signin_with_twitter=False, access_type=None)
#      |      Get the authorization URL to redirect the user
#      |
#      |  get_username(self)
#      |
#      |  get_xauth_access_token(self, username, password)
#      |      Get an access token from an username and password combination.
#      |      In order to get this working you need to create an app at
#      |      http://twitter.com/apps, after that send a mail to api@twitter.com
#      |      and request activation of xAuth for it.
#      |
#      |  set_access_token(self, key, secret)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  OAUTH_HOST = 'api.twitter.com'
#      |
#      |  OAUTH_ROOT = '/oauth/'
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from AuthHandler:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#
# DATA
#     WARNING_MESSAGE = 'Warning! Due to a Twitter API bug, signin_with_t......
#     print_function = _Feature((2, 6, 0, 'alpha', 2), (3, 0, 0, 'alpha', 0)...
# ---------------------------------------------------------------------------
# TweepError                                Traceback (most recent call last)
# <ipython-input-1-3bddde988af6> in <module>()
#      24
#      25
# ---> 26 users = api.lookup_users(screen_names='isaacrael')
#      27 print(users)
#
# /home/isaac/.virtualenvs/sci_py/lib/python2.7/site-packages/tweepy/api.pyc in lookup_users(self, user_ids, screen_names, include_entities)
#     320             post_data['screen_name'] = list_to_csv(screen_names)
#     321
# --> 322         return self._lookup_users(post_data=post_data)
#     323
#     324     @property
#
# /home/isaac/.virtualenvs/sci_py/lib/python2.7/site-packages/tweepy/binder.pyc in _call(*args, **kwargs)
#     243             return method
#     244         else:
# --> 245             return method.execute()
#     246
#     247     # Set pagination mode
#
# /home/isaac/.virtualenvs/sci_py/lib/python2.7/site-packages/tweepy/binder.pyc in execute(self)
#     187                                                 proxies=self.api.proxy)
#     188                 except Exception as e:
# --> 189                     raise TweepError('Failed to send request: %s' % e)
#     190                 rem_calls = resp.headers.get('x-rate-limit-remaining')
#     191                 if rem_calls is not None:
#
# TweepError: Failed to send request: local variable 'auth' referenced before assignment
