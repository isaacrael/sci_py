# %% [markdown]
# ## Carbon Black Testing

# %% [markdown]
# [T Read The Docs](http://docs.tweepy.org/en/v3.5.0/)

# %% [markdown]
# [M Account](https://twitter.com/isaacrael)

# %% [markdown]
# [T Getting More](https://www.forbes.com/forbes/welcome/?toURL=https://www.forbes.com/sites/jaysondemers/2015/06/17/50-free-ways-to-increase-your-twitter-followers/&refURL=https://www.google.com&referrer=https://www.google.com)

# %%
import tweepy

# Calling help and various twitter.api modules
# help(tweepy.auth)
help(tweepy.api)


# Keys needed for authentication purposes
consumer_key = "JRSzaMcADzpjqWiu8mviGeJWx"
consumer_secret = "T0gDLHl7o9FYx0VJ18h6oiR68kPwi7qIcLoeHGQEWBMmj7k2vj"
access_token = "100592963-hFkQOpwfnhksoV8kywWOQqTDeKrE863qrtgmCNKn"
access_token_secret = "hP7GsXMDMxm2o7Wx3hLokaL75XzzwBiXPYXpU4YbsYpOz"

# Authentication is done below

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

"""
public_tweets = api.home_timeline()
for tweet in public_tweets:
    print tweet.text
"""

# Simple look ups via the Twitter API refer to Twitter documentation


users = api.lookup_users(screen_names='isaacrael')
print(users)

me = api.me()
print("This is me!\n")
print(me)

# Create my_frienships Object and print my_friend_ships
my_friendships = api.lookup_friendships(screen_names='isaacrael')
print(my_friendships)


# Create my_list

my_list = api.create_list(name='my_favorite_list')

# Get my lists

#get_my_list = api.get_list(owner_screen_name='isaacrael')
#print(get_my_list)

# Send direct message

send_direct_message = api.send_direct_message(screen_name='isaacrael', text='Gil Have An Awesome Weekend...Buddy!')


my_followers = api.followers(screen_name='isaacrael')
print(my_followers)


my_friendship = api.create_friendship(screen_name='mcuban', follow='true')
# Out:
# Help on API in module tweepy.api object:
#
# class API(__builtin__.object)
#  |  Twitter API
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, auth_handler=None, host='api.twitter.com', search_host='search.twitter.com', upload_host='upload.twitter.com', cache=None, api_root='/1.1', search_root='', upload_root='/1.1', retry_count=0, retry_delay=0, retry_errors=None, timeout=60, parser=None, compression=False, wait_on_rate_limit=False, wait_on_rate_limit_notify=False, proxy='')
#  |      Api instance Constructor
#  |
#  |      :param auth_handler:
#  |      :param host:  url of the server of the rest api, default:'api.twitter.com'
#  |      :param search_host: url of the search server, default:'search.twitter.com'
#  |      :param upload_host: url of the upload server, default:'upload.twitter.com'
#  |      :param cache: Cache to query if a GET method is used, default:None
#  |      :param api_root: suffix of the api version, default:'/1.1'
# ...
